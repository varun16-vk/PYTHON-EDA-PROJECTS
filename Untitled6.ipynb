# %% [markdown]
# ## EDA

# %% [markdown]
# ## Exploratory Data Analysis
#
# It is the process to know more about the data.
#
# It is exploring the data.
#
# It is the process to have a look upon the data from different angles and perspectives.
#
# It is the process to understand the different aspects of the data.

# %% [markdown]
# ## Steps
# shape
#
# Basic information (datatypes)
#
# Column name
#
# Statistical summary
#
# Check for the null values
#
# Check for the duplicate values
#
# Check for the outliers
#
# Treat the null values
#
# Treat the duplicate values
#
# Treat the outliers
#
# Check for coorelation
#
# Analysis

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## loading the data set from the seaborn

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_base',
#  '_compat',
#  '_core',
#  '_docstrings',
#  '_orig_rc_params',
#  '_statistics',
#  '_stats',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
#  'histplot',
# ...

# %% [markdown]
# ## loading the data set

# %%
sd=sns.load_dataset("titanic")

# %%
sd
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## shape

# %%
sd.shape
# Out:
# (891, 15)

# %% [markdown]
# ## size

# %%
sd.size
# Out:
# 13365

# %% [markdown]
# ## Basic Information

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ## columns

# %%
sd.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# ## Statistical summary

# %%
sd.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sd.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# ## Check for the duplicate values and drop the duplicate values

# %%
sd.duplicated().sum()
# Out:
# 107

# %%
sd[sd.duplicated()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 76          0       3    male   NaN      0      0   7.8958        S   Third
# 77          0       3    male   NaN      0      0   8.0500        S   Third
# 87          0       3    male   NaN      0      0   8.0500        S   Third
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sd.drop_duplicates(inplace=True)

# %%
sd.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## checking the unique value from each colunms

# %%
sd.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %% [markdown]
# ## Treating the null values
# We can drop the null values
#
# We can impute the null values (filling the null values with some other values like mean values for integers and float & mode value for string)
#
# Before filling the null values we have to check whether a column is discrete or cataegorical

# %% [markdown]
# ## checking the percentage of null values in a columns

# %%
sd.isna().sum()/len(sd)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            13.520408
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.255102
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           74.234694
# embark_town     0.255102
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# ## count of null values in a columns

# %%
sd.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sd.age.isna().sum()
# Out:
# 106

# %%
sd.age.mean()
# Out:
# 29.869351032448375

# %%
sd.age.fillna(sd.age.mean(),inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14744\3212066416.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sd.age.fillna(sd.age.mean(),inplace=True)

# %%
sd.age.isna().sum()
# Out:
# 0

# %% [markdown]
# ## deck

# %%
sd.deck.mode()
# Out:
# 0    C
# Name: deck, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
sd.deck.value_counts()
# Out:
# deck
# C    59
# B    46
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
sd.deck.fillna(sd.deck.mode()[0],inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14744\4023954307.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sd.deck.fillna(sd.deck.mode()[0],inplace=True)

# %%
sd.deck.isna().sum()
# Out:
# 0

# %%
sd.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ## embarked

# %%
sd.embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 885    Q
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 784, dtype: object

# %%
sd.embarked.mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
sd.embarked.fillna(sd.embarked.mode()[0],inplace=True)

# %%
sd.embarked.isna().sum()
# Out:
# 0

# %%
sd.embark_town.isna().sum()
# Out:
# 2

# %%
sd.embark_town.fillna(sd.embark_town.mode()[0],inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14744\3001655748.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sd.embark_town.fillna(sd.embark_town.mode()[0],inplace=True)

# %%
sd.embark_town.isna().sum()
# Out:
# 0

# %%
sd.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ## droping the columns "class","alive","embarked"

# %%
sd.drop(["class","alive","embarked"],axis=1,inplace=True)

# %%
sd
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare    who  \
# 0           0       3    male  22.000000      1      0   7.2500    man
# 1           1       1  female  38.000000      1      0  71.2833  woman
# 2           1       3  female  26.000000      0      0   7.9250  woman
# 3           1       1  female  35.000000      1      0  53.1000  woman
# 4           0       3    male  35.000000      0      0   8.0500    man
# ..        ...     ...     ...        ...    ...    ...      ...    ...
# 885         0       3  female  39.000000      0      5  29.1250  woman
# 887         1       1  female  19.000000      0      0  30.0000  woman
# 888         0       3  female  29.869351      1      2  23.4500  woman
# 889         1       1    male  26.000000      0      0  30.0000    man
# 890         0       3    male  32.000000      0      0   7.7500    man
#
#      adult_male deck  embark_town  alone
# 0          True    C  Southampton  False
# ...

# %% [markdown]
# ## checking the unique values from each columns

# %%
sd.embark_town.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %%
sd.deck.unique()
# Out:
# ['C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
sd.deck.value_counts()
# Out:
# deck
# C    641
# B     46
# D     33
# E     32
# A     15
# F     13
# G      4
# Name: count, dtype: int64

# %%
sd.sibsp.unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
sd.parch.unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 784 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int64
#  1   pclass       784 non-null    int64
#  2   sex          784 non-null    object
#  3   age          784 non-null    float64
#  4   sibsp        784 non-null    int64
#  5   parch        784 non-null    int64
#  6   fare         784 non-null    float64
#  7   who          784 non-null    object
#  8   adult_male   784 non-null    bool
#  9   deck         784 non-null    category
#  10  embark_town  784 non-null    object
#  11  alone        784 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(3)
# memory usage: 63.9+ KB

# %% [markdown]
# ## renaming the columns

# %%
sd.rename(columns={"who":"people_idenity"},inplace=True)

# %% [markdown]
# ## creating a new columns where changing sex columns male & female to gender 1 & 0

# %%
sd["gender"]=np.where(sd.sex=="male",1,0)

# %%
sd
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare  \
# 0           0       3    male  22.000000      1      0   7.2500
# 1           1       1  female  38.000000      1      0  71.2833
# 2           1       3  female  26.000000      0      0   7.9250
# 3           1       1  female  35.000000      1      0  53.1000
# 4           0       3    male  35.000000      0      0   8.0500
# ..        ...     ...     ...        ...    ...    ...      ...
# 885         0       3  female  39.000000      0      5  29.1250
# 887         1       1  female  19.000000      0      0  30.0000
# 888         0       3  female  29.869351      1      2  23.4500
# 889         1       1    male  26.000000      0      0  30.0000
# 890         0       3    male  32.000000      0      0   7.7500
#
#     people_idenity  adult_male deck  embark_town  alone  gender
# 0              man        True    C  Southampton  False       1
# 1            woman       False    C    Cherbourg  False       0
# ...

# %% [markdown]
# # changing the survived columns from 0 & 1  into survived and unsurvived

# %%
sd['new_survived']=sd.survived.apply(lambda x:"unsurvived" if x== 0 else "survived")

# %%
sd
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare  \
# 0           0       3    male  22.000000      1      0   7.2500
# 1           1       1  female  38.000000      1      0  71.2833
# 2           1       3  female  26.000000      0      0   7.9250
# 3           1       1  female  35.000000      1      0  53.1000
# 4           0       3    male  35.000000      0      0   8.0500
# ..        ...     ...     ...        ...    ...    ...      ...
# 885         0       3  female  39.000000      0      5  29.1250
# 887         1       1  female  19.000000      0      0  30.0000
# 888         0       3  female  29.869351      1      2  23.4500
# 889         1       1    male  26.000000      0      0  30.0000
# 890         0       3    male  32.000000      0      0   7.7500
#
#     people_idenity  adult_male deck  embark_town  alone  gender new_survived
# 0              man        True    C  Southampton  False       1   unsurvived
# ...

# %%
q=sd.select_dtypes("number")

# %%
q
# Out:
#      survived  pclass        age  sibsp  parch     fare  gender
# 0           0       3  22.000000      1      0   7.2500       1
# 1           1       1  38.000000      1      0  71.2833       0
# 2           1       3  26.000000      0      0   7.9250       0
# 3           1       1  35.000000      1      0  53.1000       0
# 4           0       3  35.000000      0      0   8.0500       1
# ..        ...     ...        ...    ...    ...      ...     ...
# 885         0       3  39.000000      0      5  29.1250       0
# 887         1       1  19.000000      0      0  30.0000       0
# 888         0       3  29.869351      1      2  23.4500       0
# 889         1       1  26.000000      0      0  30.0000       1
# 890         0       3  32.000000      0      0   7.7500       1
#
# [784 rows x 7 columns]

# %%
sd.isna().sum()
# Out:
# survived          0
# pclass            0
# sex               0
# age               0
# sibsp             0
# parch             0
# fare              0
# people_idenity    0
# adult_male        0
# deck              0
# embark_town       0
# alone             0
# gender            0
# new_survived      0
# dtype: int64

# %% [markdown]
# ## checking for the outliners in every columns

# %% [markdown]
# ## survived

# %%
sns.boxplot(y="survived",data=sd)
# Out:
# <Axes: ylabel='survived'>

# %% [markdown]
# ## pclass

# %%
sns.boxplot(y="pclass",data=sd)
# Out:
# <Axes: ylabel='pclass'>

# %% [markdown]
# ## age

# %%
sns.boxplot(y="age",data=sd)
# Out:
# <Axes: ylabel='age'>

# %%
sd.age.describe()
# Out:
# count    784.000000
# mean      29.869351
# std       13.723745
# min        0.420000
# 25%       22.000000
# 50%       29.869351
# 75%       36.000000
# max       80.000000
# Name: age, dtype: float64

# %%
q1=22
q3=36
q1,q3
# Out:
# (22, 36)

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 14

# %%
lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr

# %%
lower_limit,upper_limit
# Out:
# (1.0, 57.0)

# %%
sd[(sd["age"]<lower_limit) | (sd["age"]>upper_limit)]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare people_idenity  \
# 11          1       1  female  58.00      0      0   26.5500          woman
# 33          0       2    male  66.00      0      0   10.5000            man
# 54          0       1    male  65.00      0      1   61.9792            man
# 78          1       2    male   0.83      0      2   29.0000          child
# 94          0       3    male  59.00      0      0    7.2500            man
# 96          0       1    male  71.00      0      0   34.6542            man
# 116         0       3    male  70.50      0      0    7.7500            man
# 170         0       1    male  61.00      0      0   33.5000            man
# 195         1       1  female  58.00      0      0  146.5208          woman
# 232         0       2    male  59.00      0      0   13.5000            man
# 252         0       1    male  62.00      0      0   26.5500            man
# ...

# %%
sd.loc[(sd["age"]<lower_limit),"age"]=lower_limit
sd.loc[(sd["age"]>upper_limit),"age"]=upper_limit

# %%
sns.boxplot(y="age",data=sd)
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# ## fare

# %%
sns.boxplot(y="fare",data=sd)
# Out:
# <Axes: ylabel='fare'>

# %%
def outliners (data):
    q1=data.quantile(0.25)
    q3=data.quantile(0.75)

    iqr=q3-q1
    upper_bound=q3+1.5*iqr
    lower_bound=q1-1.5*iqr
    
    return data.clip(upper_bound,lower_bound)

# %%
sd["fare_new"]=outliners(sd.fare)

# %%
sd[["fare","fare_new"]].describe()
# Out:
#              fare    fare_new
# count  784.000000  784.000000
# mean    34.711740   26.492784
# std     52.160151   22.762166
# min      0.000000    0.000000
# 25%      8.050000    8.050000
# 50%     15.900000   15.900000
# 75%     34.109350   34.109350
# max    512.329200   73.198375

# %%
sns.boxplot(y="fare_new",data=sd)
# Out:
# <Axes: ylabel='fare_new'>

# %% [markdown]
# ## parch

# %%
sns.boxplot(y="parch",data=sd)
# Out:
# <Axes: ylabel='parch'>

# %%
sd.parch.describe()
# Out:
# count    784.000000
# mean       0.415816
# std        0.836922
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        6.000000
# Name: parch, dtype: float64

# %%
q1=0
q3=1

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 1

# %%
lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr

# %%
lower_limit,upper_limit
# Out:
# (-1.5, 2.5)

# %%
sd[(sd.parch<lower_limit) | (sd.parch>upper_limit)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare people_idenity  \
# 13          0       3    male  39.0      1      5   31.2750            man
# 25          1       3  female  38.0      1      5   31.3875          woman
# 86          0       3    male  16.0      1      3   34.3750            man
# 167         0       3  female  45.0      1      4   27.9000          woman
# 360         0       3    male  40.0      1      4   27.9000            man
# 437         1       2  female  24.0      2      3   18.7500          woman
# 438         0       1    male  57.0      1      4  263.0000            man
# 567         0       3  female  29.0      0      4   21.0750          woman
# 610         0       3  female  39.0      1      5   31.2750          woman
# 638         0       3  female  41.0      0      5   39.6875          woman
# 678         0       3  female  43.0      1      6   46.9000          woman
# ...

# %%
sd.loc[(sd.parch<lower_limit),"parch"]= lower_limit
sd.loc[(sd.parch>upper_limit),"parch"]=upper_limit
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14744\3838651562.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-1.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sd.loc[(sd.parch<lower_limit),"parch"]= lower_limit

# %%
sns.boxplot(y="parch",data=sd)
# Out:
# <Axes: ylabel='parch'>

# %% [markdown]
# # total count of male and female in titan ship

# %%
aq=sns.countplot(x="sex",data=sd)
for i in aq.containers:
     aq.bar_label(i)

# %% [markdown]
# # total numbers of man,women & child traveled in the titan ship

# %%
aq=sns.countplot(x="people_idenity",data=sd)
for i in aq.containers:
     aq.bar_label(i)

# %% [markdown]
# # total survived and unsurvived people count in the titan ship

# %%
aq=sns.countplot(x="new_survived",data=sd)
for i in aq.containers:
     aq.bar_label(i)

# %% [markdown]
# # count of people embarded their jounery from which town

# %%
aq=sns.countplot(x="embark_town",data=sd)
for i in aq.containers:
     aq.bar_label(i)

# %%
sd
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare  \
# 0           0       3    male  22.000000      1      0   7.2500
# 1           1       1  female  38.000000      1      0  71.2833
# 2           1       3  female  26.000000      0      0   7.9250
# 3           1       1  female  35.000000      1      0  53.1000
# 4           0       3    male  35.000000      0      0   8.0500
# ..        ...     ...     ...        ...    ...    ...      ...
# 885         0       3  female  39.000000      0      5  29.1250
# 887         1       1  female  19.000000      0      0  30.0000
# 888         0       3  female  29.869351      1      2  23.4500
# 889         1       1    male  26.000000      0      0  30.0000
# 890         0       3    male  32.000000      0      0   7.7500
#
#     people_idenity  adult_male deck  embark_town  alone  gender new_survived
# 0              man        True    C  Southampton  False       1   unsurvived
# ...
